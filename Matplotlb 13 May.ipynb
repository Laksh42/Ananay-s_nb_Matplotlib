# %% [markdown]
# ### Line Plot

# %%
import matplotlib.pyplot as plt
x=[5,10,15,20,25,30,35]
y=[14,64,23,78,54,96,45]
z=[98,67,56,43,12,34,68]

plt.xlim(0,40)
plt.ylim(0,120)

plt.text(1,110,"Itronix",fontsize=15,fontname='Times New Roman',color='cyan',weight='bold')

plt.title('Title',fontsize=20,fontname='Times New Roman',color='#0d1af3',weight='bold')
plt.xlabel('Time',fontsize=20,fontname='Times New Roman',color='#0d1af3',weight='bold')
plt.ylabel('Sensor',fontsize=20,fontname='Times New Roman',color='#0d1af3',weight='bold')

plt.plot(x,y,label='Sensor 1',linewidth=3,color='r',linestyle='dashed')
plt.plot(x,z,label='Sensor 2',linewidth=3,marker='o',markersize=8, markerfacecolor='k')

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=[5,10,15,20,25,30,35]
y=[14,64,23,78,54,96,45]
z=[98,67,56,43,12,34,68]

plt.axis([0,40,0,120])

plt.text(1,110,"Itronix",fontsize=15,fontname='Times New Roman',color='cyan',weight='bold')

plt.title('Title',fontsize=20,fontname='Times New Roman',color='#0d1af3',weight='bold')
plt.xlabel('Time',fontsize=20,fontname='Times New Roman',color='#0d1af3',weight='bold')
plt.ylabel('Sensor',fontsize=20,fontname='Times New Roman',color='#0d1af3',weight='bold')

plt.plot(x,y,label='Sensor 1',linewidth=3,color='r',linestyle='dashed')
plt.plot(x,z,label='Sensor 2',linewidth=3,marker='o',markersize=8, markerfacecolor='k')

plt.legend()
plt.savefig('itronix.pdf')
plt.show()

# %%
import numpy as np
x=np.arange(1,16)
y=7*x+3
plt.plot(x,y,'ro')
plt.plot(x,y**2,'b^')
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[10,20,15,18,7,19]

xlabels=['Jan','Feb','Mar','Apr','May','Jun']
plt.plot(x,y)
plt.xticks(x,xlabels,rotation=45)

plt.show()

# %% [markdown]
# ### Bar Plot

# %%
import matplotlib.pyplot as plt
x=[5,10,15,20,25,30,35]
y=[14,64,23,78,54,96,45]
z=[98,67,56,43,12,34,68]

plt.axis([0,40,0,120])

plt.text(1,110,"Itronix",fontsize=15,fontname='Times New Roman',color='cyan',weight='bold')

plt.title('Title',fontsize=20,fontname='Times New Roman',color='#0d1af3',weight='bold')
plt.xlabel('Time',fontsize=20,fontname='Times New Roman',color='#0d1af3',weight='bold')
plt.ylabel('Sensor',fontsize=20,fontname='Times New Roman',color='#0d1af3',weight='bold')

plt.bar(x,y,label='Sensor 1',color='r',width=3)
plt.bar(x,z,label='Sensor 2',width=3,alpha=0.6)

plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
x=[5,10,15,20,25,30,35]
y=[14,64,23,78,54,96,45]
z=[98,67,56,43,12,34,68]

plt.text(1,110,"Itronix",fontsize=15,fontname='Times New Roman',color='cyan',weight='bold')

plt.title('Title',fontsize=20,fontname='Times New Roman',color='#0d1af3',weight='bold')
plt.xlabel('Time',fontsize=20,fontname='Times New Roman',color='#0d1af3',weight='bold')
plt.ylabel('Sensor',fontsize=20,fontname='Times New Roman',color='#0d1af3',weight='bold')

plt.bar(x,y,label='Sensor 1',tick_label=['M','T','W','T','F','S','S'],color='r',width=3)

plt.legend()
plt.show()

# %%
import numpy as np

M=[20,35,30,35,27]
F=[25,32,34,20,25]
x=np.arange(len(M))

plt.bar(x,M,width=0.35)
plt.bar(x+0.35,F,width=.35)

plt.xticks(x+0.35/2,('G1','G2','G3','G4','G5'))
plt.show()

# %%
import numpy as np

M=[20,35,30,35,27]
F=[25,32,34,20,25]
x=np.arange(len(M))

plt.ylim(0,40)
plt.title('Title')
plt.xlabel('Gender')
plt.ylabel('Age')

a=plt.bar(x,M,width=0.35,label='Male')
b=plt.bar(x+0.35,F,width=.35,label='Female')

for value in a:
    height=value.get_height()
    plt.text(value.get_x()+value.get_width()/2,1.04*height,'%.0f'%float(height),ha='center',va='bottom')
    

for value in b:
    height=value.get_height()
    plt.text(value.get_x()+value.get_width()/2,1.04*height,'%.0f'%float(height),ha='center',va='bottom')

plt.xticks(x+0.35/2,('G1','G2','G3','G4','G5'))
plt.legend()
plt.show()

# %%
from matplotlib import style
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
import numpy as np
from matplotlib import style
style.use('ggplot')

M=[20,35,30,35,27]
F=[25,32,34,20,25]
x=np.arange(len(M))

plt.ylim(0,40)
plt.title('Title')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.grid(True,color='k')

a=plt.bar(x,M,width=0.35,label='Male')
b=plt.bar(x+0.35,F,width=.35,label='Female')

for value in a:
    height=value.get_height()
    plt.text(value.get_x()+value.get_width()/2,1.04*height,'%.0f'%float(height),ha='center',va='bottom')
    

for value in b:
    height=value.get_height()
    plt.text(value.get_x()+value.get_width()/2,1.04*height,'%.0f'%float(height),ha='center',va='bottom')

plt.xticks(x+0.35/2,('G1','G2','G3','G4','G5'))
plt.legend()
#plt.savefig('foo.png', transparent=True)
plt.show()

# %%
import numpy as np
data = np.genfromtxt('file.csv', delimiter=',', dtype=str)
x=data[:,0].astype('float')
y=data[:,1].astype('float')

plt.xticks(np.arange(min(x), max(x)+1, 1.0))
plt.yticks(np.arange(min(y), max(y)+1, 1.0))

plt.plot(x,y)
plt.show()

# %%
import numpy as np
x,y = np.loadtxt('file.csv',unpack=True,delimiter = ',')
plt.plot(x,y)

plt.xticks(np.arange(min(x), max(x)+1, 1.0))
plt.yticks(np.arange(min(y), max(y)+1, 1.0))

plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
import matplotlib.pyplot as plt
x=[5,10,15,20,25,30,35]
y=[14,64,23,78,54,96,45]
z=[98,67,56,43,12,34,68]

plt.axis([0,40,0,120])

plt.text(1,110,"Itronix",fontsize=15,fontname='Times New Roman',color='cyan',weight='bold')

plt.title('Title',fontsize=20,fontname='Times New Roman',color='#0d1af3',weight='bold')
plt.xlabel('Time',fontsize=20,fontname='Times New Roman',color='#0d1af3',weight='bold')
plt.ylabel('Sensor',fontsize=20,fontname='Times New Roman',color='#0d1af3',weight='bold')

plt.scatter(x,y,label='Sensor 1')
plt.scatter(x,z,label='Sensor 2')

plt.legend()
plt.show()

# %% [markdown]
# ### Pie Chart

# %%
plt.title("Itronix Solutions : Pie Chart")
slices=[40,10,10,10,30]
cols=['red','green','b','cyan','y']
channels=['9X','Sony','Star Plus','Colors','Cartoon Network']

plt.pie(slices,colors=cols,labels=channels,explode=(0,0,0.3,0,0),autopct='%.2f%%')
plt.legend(loc="upper right",fontsize=12,bbox_to_anchor=(1.65,0.8))
plt.show()
